# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/anonymized_bsc_dataPVZ.csv')
# Out:
# /Users/clementinelacey/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (18,20,21,23,24,26,27,29,31,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#   Sttr Term      course_#                course_title Sttr Student Load  \
# 0     15/SP      DA 101 A                Basic Ballet                 F
# 1     15/SP   HI 155 A-ES           Reforming America                 F
# 2     15/SP   PL 200 A-CI              Ethical Choice                 F
# 3     15/SP  IDS 200 A-CI  Intro to Human Rights (GP)                 F
# 4     15/WI   GEN E299 49         Exploration Project                 F
#
#    Sttr Stu Credits  Sttr Attempted Cred Sttr Stu Final Grades  \
# 0               0.5                  3.0                     W
# 1               1.0                  NaN                    A-
# 2               1.0                  NaN                    B+
# 3               1.0                  NaN                     A
# 4               1.0                  1.0                     S
#
#    Sttr Cmpl Cred  Sttr Term Gpa            faculty  ...  FA5 Enr FA5 Class  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51537 entries, 0 to 51536
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sttr Term              51518 non-null  object
#  1   course_#               51518 non-null  object
#  2   course_title           51518 non-null  object
#  3   Sttr Student Load      51417 non-null  object
#  4   Sttr Stu Credits       51479 non-null  float64
#  5   Sttr Attempted Cred    46383 non-null  float64
#  6   Sttr Stu Final Grades  51518 non-null  object
#  7   Sttr Cmpl Cred         51417 non-null  float64
#  8   Sttr Term Gpa          51417 non-null  float64
#  9   faculty                51478 non-null  object
#  10  alt_id                 51518 non-null  float64
#  11  Cohort                 51537 non-null  object
#  12  SP1 Enr                50912 non-null  object
#  13  SP1 Class              50912 non-null  float64
# ...

# %%
df_Student = df.groupby(level=0)

# %%
df.drop(df.index[51518:51537], inplace=True)

# %%
df.head()
# Out:
#   Sttr Term      course_#                course_title Sttr Student Load  \
# 0     15/SP      DA 101 A                Basic Ballet                 F
# 1     15/SP   HI 155 A-ES           Reforming America                 F
# 2     15/SP   PL 200 A-CI              Ethical Choice                 F
# 3     15/SP  IDS 200 A-CI  Intro to Human Rights (GP)                 F
# 4     15/WI   GEN E299 49         Exploration Project                 F
#
#    Sttr Stu Credits  Sttr Attempted Cred Sttr Stu Final Grades  \
# 0               0.5                  3.0                     W
# 1               1.0                  NaN                    A-
# 2               1.0                  NaN                    B+
# 3               1.0                  NaN                     A
# 4               1.0                  1.0                     S
#
#    Sttr Cmpl Cred  Sttr Term Gpa            faculty  ...  FA5 Enr FA5 Class  \
# ...

# %%
df = pd.get_dummies(df, columns=['course_title', 'faculty'])

# %%
df.columns = df.columns.str.replace('faculty_', '')
df.columns = df.columns.str.replace('course_title','')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51518 entries, 0 to 51517
# Columns: 1313 entries, Sttr Term to Zhengyang Chen
# dtypes: float64(12), object(20), uint8(1281)
# memory usage: 75.9+ MB

# %%
df.head()
# Out:
#   Sttr Term      course_# Sttr Student Load  Sttr Stu Credits  \
# 0     15/SP      DA 101 A                 F               0.5
# 1     15/SP   HI 155 A-ES                 F               1.0
# 2     15/SP   PL 200 A-CI                 F               1.0
# 3     15/SP  IDS 200 A-CI                 F               1.0
# 4     15/WI   GEN E299 49                 F               1.0
#
#    Sttr Attempted Cred Sttr Stu Final Grades  Sttr Cmpl Cred  Sttr Term Gpa  \
# 0                  3.0                     W             3.0          3.667
# 1                  NaN                    A-             3.0          3.667
# 2                  NaN                    B+             3.0          3.667
# 3                  NaN                     A             3.0          3.667
# 4                  1.0                     S             1.0          0.000
#
#    alt_id Cohort  ... William Holt  William Hustwit William Jackson  \
# ...

# %%
df.columns
# Out:
# Index(['Sttr Term', 'course_#', 'Sttr Student Load', 'Sttr Stu Credits',
#        'Sttr Attempted Cred', 'Sttr Stu Final Grades', 'Sttr Cmpl Cred',
#        'Sttr Term Gpa', 'alt_id', 'Cohort',
#        ...
#        'William Holt', 'William Hustwit', 'William Jackson', 'William Miller',
#        'William Myers', 'Wyley Shreves', 'Yahui Huang', 'Yosra Ouertani',
#        'Zakaria Enikeev', 'Zhengyang Chen'],
#       dtype='object', length=1313)

# %%
df.alt_id = df.alt_id.astype(int)

# %%
dfstudent = df.groupby('alt_id')

# %%
from sklearn.model_selection import train_test_split

# %%
target = df['Graduated']

# %%
df_data = df.loc[(df['Cohort'] == '14/FA') | (df['Cohort'] == '15/FA') | (df['Cohort'] == '16/FA')
              | (df['Cohort'] == '17/FA')]
df_data = df_data.dropna(subset=['Sttr Term'])
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40886 entries, 0 to 41083
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sttr Term              40886 non-null  object
#  1   course_#               40886 non-null  object
#  2   course_title           40886 non-null  object
#  3   Sttr Student Load      40852 non-null  object
#  4   Sttr Stu Credits       40883 non-null  float64
#  5   Sttr Attempted Cred    36642 non-null  float64
#  6   Sttr Stu Final Grades  40886 non-null  object
#  7   Sttr Cmpl Cred         40852 non-null  float64
#  8   Sttr Term Gpa          40852 non-null  float64
#  9   faculty                40883 non-null  object
#  10  alt_id                 40886 non-null  float64
#  11  Cohort                 40886 non-null  object
#  12  SP1 Enr                40415 non-null  object
#  13  SP1 Class              40415 non-null  float64
# ...

# %%
#Loop over ever alt_id to find classes and append to list, then make a lists of these lists
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-bd1c5a4ae36b> in <module>
# ----> 1 df_data.sort('Cohort')
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'
